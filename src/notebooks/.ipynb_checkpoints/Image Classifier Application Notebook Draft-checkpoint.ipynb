# %%
import torch
import bcolz as bz
import pickle
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
import time
import os 
import copy
import ast
from PIL import Image
from torchvision import datasets, models, transforms
from torch.autograd import Variable
# import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# Hyperparameters
batch_size = 4
num_classes = 133
num_features = 2048
learning_rate = 1e-2
num_epochs = 500
step_size=7
gamma=0.1
weight_decay=1e-5

# %%
#save paths
model_weights_path = '../models/checkpoint.pth.tar'
data_base_path = '../data/raw/dogImages'
class_to_idx_path = '../models/class_to_idx.pkl'

# %%
#Data Transforms
preprocess = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 406], [0.229, 0.224, 0.225])
    ])
}


image_datasets = {x: datasets.ImageFolder(os.path.join(data_base_path, x), preprocess[x]) for x in ['train', 'valid']}
dataLoaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=1) for x in ['train', 'valid']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'valid']}
class_names = image_datasets['train'].classes
class_to_idx = image_datasets['train'].class_to_idx
# print('class_names', class_names)
# print('class_to_idx', class_to_idx)
use_gpu = torch.cuda.is_available()

# %%
pickle.dump((class_to_idx,), open(class_to_idx_path, 'wb'))

# %%
class_to_index = pickle.load(open(class_to_idx_path, mode='rb'))
# print('class_to_index', class_to_index)

# %%
# sample images
def imshow(inp, title=None):
    """imshow for tensor"""
    inp = inp.numpy().transpose((1,2,0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0,1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated

# get a batch of training data
inputs, classes = next(iter(dataLoaders['train']))
#make a grid from batch
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    start = time.time()
    best_model_weights = copy.deepcopy(model.state_dict())
    best_accuracy = 0.0
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs -1))
        print('-'*10)
        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                scheduler.step()
                model.train(True)
            else:
                model.train(False)
            running_loss = 0.0
            running_corrects = 0
            
            # Iterate over data
            for data in dataLoaders[phase]:
                inputs, labels = data
                if use_gpu:
                    inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
                else:
                    inputs, labels = Variable(inputs), Variable(labels)
                optimizer.zero_grad()
                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)
                if phase == 'train':
                    loss.backward()
                    optimizer.step()
                running_loss += loss.data[0] * inputs.size(0)
                running_corrects += torch.sum(preds==labels.data)
            epoch_loss = running_loss/dataset_sizes[phase]
            epoch_accuracy = running_corrects/dataset_sizes[phase]
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_accuracy))
            
            if phase == 'valid' and epoch_accuracy > best_accuracy:
                best_accuracy = epoch_accuracy
                best_model_weights = copy.deepcopy(model.state_dict())
        print()
    
    run_time = time.time() - start
    print('Training completed in {:.0f}m and {:.0f}s'.format(run_time//60, run_time%60))
    print('Best Validation Accuracy: {:4f}'.format(best_accuracy))
    model.load_state_dict(best_model_weights)
    return model

# %%
def visualize_model(model, num_images):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()
    for i, data in enumerate(dataLoaders['valid']):
        inputs, labels = data
        if use_gpu:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)
        outputs = models(inputs)
        _, preds = torch.max(outputs.data, 1)
        for k in range(inputs.size()[0]):
            images_so_far += 1
            ax = plt.subplot(num_images//2, 2, image_so_far)
            ax.axis('off')
            ax.set_title('Predicted: {}'.format(class_names[preds[k]]))
            imshow(inputs.cpu().data[k])
            if images_so_far == num_images:
                model.train(mode=was_training)
                return
    model.train(mode=was_training)

# %%
pretrained_model = models.resnet152(pretrained=True)
# num_features = vgg19_bn.classifier.in_features
modules = list(pretrained_model.children())[:-1]
pretrained_model=nn.Sequential(*modules)
for param in pretrained_model.parameters():
    param.requires_grad = False
if use_gpu:
    pretrained_model = pretrained_model.cuda()

# %%
def save_array(filename, arr):
    c=bz.carray(arr, rootdir=filename, mode='w')
    c.flush()

# %%
def load_array(filename):
    return bz.open(filename)[:]

# %%
#Reference: 
def extract_features(dataset):
    features = []
    labels_list = []
    for data in dataset:
        inputs, labels = data
        if use_gpu:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)
        x = pretrained_model(inputs)
        features.extend(x.data.cpu().numpy())
        labels_list.extend(labels.data.cpu().numpy())
    features = np.concatenate([[feat] for feat in features])
    return (features, labels_list)

# %%
# %%time
conv_feat_train, labels_train = extract_features(dataLoaders['train'])
# Out:
# CPU times: user 1h 2min 25s, sys: 8min 12s, total: 1h 10min 37s
# Wall time: 45min 10s

# %%
save_array('../data/processed/conv_feat_train.bc', conv_feat_train)

# %%
save_array('../data/processed/labels_train.bc', labels_train)

# %%
# %%time
conv_feat_val, labels_val = extract_features(dataLoaders['valid'])
# Out:
# CPU times: user 7min 48s, sys: 1min 1s, total: 8min 50s
# Wall time: 5min 45s

# %%
save_array('../data/processed/conv_feat_val.bc', conv_feat_val)

# %%
save_array('../data/processed/labels_val.bc', labels_val)

# %%
conv_feat_train = load_array('../data/processed/conv_feat_train.bc')
labels_train = load_array('../data/processed/labels_train.bc')
conv_feat_val = load_array('../data/processed/conv_feat_val.bc')
labels_val = load_array('../data/processed/labels_val.bc')

# %%
conv_feat_train.shape
# Out:
# (6680, 2048, 1, 1)

# %%
np.array(labels_train).shape
# Out:
# (6680,)

# %%
np.array(conv_feat_val).shape
# Out:
# (835, 2048, 1, 1)

# %%
# #### Model ####
# Feedforward Classifier
class Classifier(nn.Module):
    """Resnet50 -> AvgPool -> FC()[Softmax]
    """
    def __init__(self, num_features, num_classes):
        super(Classifier, self).__init__()
#         self.drop = nn.Dropout(p=0.75)
#         self.fc = nn.Linear(num_features, num_classes)
        self.classifier = nn.Sequential(
#             nn.Linear(512 * 4, 256),
#             nn.ELU(True),
#             nn.Dropout(p=0.5),
#             nn.Linear(512 * 2, 1024),
#             nn.ELU(True),
#             nn.Dropout(p=0.4),
#             nn.Linear(1024, 512),
#             nn.ELU(True),
#             nn.Dropout(p=0.4),
#             nn.Linear(512, 256),
#             nn.ELU(True),
#             nn.Dropout(p=0.4),
#             nn.Linear(num_features, num_features),
#             nn.ELU(True),
#             nn.Dropout(),
#             nn.Linear(num_features, num_features),
#             nn.ELU(True),
#             nn.Dropout(),
            nn.Linear(2048, num_classes),
#             nn.Dropout(p=0.5),
        )

    def forward(self, x):
#         print('x.size()', x.size())
        x = x.view(x.size(0), -1)
#         x = self.drop(x)
        x = self.classifier(x)
        return x

model = Classifier(num_features, num_classes)
print(model)

# If you are running a GPU instance, load the model on GPU
if use_gpu:
    model.cuda()
# Out:
# Classifier(
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=133)
#   )
# )

# %%
weights, biases = [], []
for name, p in model.named_parameters():
   if 'bias' in name:
       biases += [p]
   else:
       weights += [p]

# %%
criterion = nn.CrossEntropyLoss()
optimizer_conv_adam = optim.SGD([
  {'params': weights},
  {'params': biases, weight_decay:0}
], lr=1e-2, momentum=0.9, weight_decay=5e-5)

# %%
def generator(features, labels, batch_size=32, shuffle=True):
    labels = np.array(labels)
    if shuffle:
        index = np.random.permutation(len(features))
        features = features[index]
        labels = labels[index]
    for i in range(0, len(features), batch_size):
        yield (features[i:i+batch_size], labels[i:i+batch_size])

# %%
def train(model, dataset_sizes=None, train_features=None, train_labels=None, val_features=None, val_labels=None, criterion=None, optimizer=None, num_epochs=25, train=True, shuffle=None):
    start = time.time()
    best_model_weights = copy.deepcopy(model.state_dict())
    best_accuracy = 0.0
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs -1))
        print('-'*10)
#         train_batches = generator(features=train_features, labels=train_labels, shuffle=shuffle, batch_size=batch_size)
#         val_batches = generator(features=val_features, labels=val_labels, shuffle=False, batch_size=batch_size)
        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            running_loss = 0.0
            running_corrects = 0
            if phase == 'train':
                train_batches = generator(features=train_features, labels=train_labels, shuffle=shuffle, batch_size=batch_size)
                #scheduler.step()
                model.train()
                for data in train_batches:
                    inputs, labels = data
                    if use_gpu:
                        inputs, labels = Variable(torch.from_numpy(inputs).cuda()), Variable(torch.from_numpy(labels).cuda())
                    else:
                        inputs, labels = Variable(torch.from_numpy(inputs)), Variable(torch.from_numpy(labels))
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    optimizer = optimizer
                    optimizer.zero_grad()
                    _, preds = torch.max(outputs.data, 1)
                    loss.backward()
                    optimizer.step()
                    running_loss += loss.data[0] * inputs.size(0)
                    running_corrects += torch.sum(preds==labels.data)
            else:
                val_batches = generator(features=val_features, labels=val_labels, shuffle=False, batch_size=batch_size)
                model.eval()
                for data in val_batches:
                    inputs, labels = data
                    if use_gpu:
                        inputs, labels = Variable(torch.from_numpy(inputs).cuda()), Variable(torch.from_numpy(labels).cuda())
                    else:
                        inputs, labels = Variable(torch.from_numpy(inputs)), Variable(torch.from_numpy(labels))
                    outputs = model(inputs)
                    _, preds = torch.max(outputs.data, 1)
                    loss = criterion(outputs, labels)
                    running_loss += loss.data[0] * inputs.size(0)
                    running_corrects += torch.sum(preds==labels.data)
            
            # Iterate over data
            epoch_loss = running_loss/dataset_sizes[phase]
            epoch_accuracy = running_corrects/dataset_sizes[phase]
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_accuracy))
            
            if phase == 'valid' and epoch_accuracy > best_accuracy:
                best_accuracy = epoch_accuracy
                best_model_weights = copy.deepcopy(model.state_dict())
        print()
    
    run_time = time.time() - start
    print('Training completed in {:.0f}m and {:.0f}s'.format(run_time//60, run_time%60))
    print('Best Validation Accuracy: {:4f}'.format(best_accuracy))
    model.load_state_dict(best_model_weights)
    return model

# %%
train(model,dataset_sizes=dataset_sizes, train_features=conv_feat_train, train_labels=labels_train, val_features=conv_feat_val, val_labels=labels_val, criterion=criterion, optimizer=optimizer_conv_adam, num_epochs=num_epochs, train=True, shuffle=True)
# Out:
# Epoch 0/499
# ----------
# train Loss: 8.9182 Acc: 0.0618
# valid Loss: 8.0061 Acc: 0.1186
#
# Epoch 1/499
# ----------
# train Loss: 7.5994 Acc: 0.1629
# valid Loss: 9.0645 Acc: 0.1449
#
# Epoch 2/499
# ----------
# train Loss: 6.7575 Acc: 0.2196
# valid Loss: 9.6168 Acc: 0.1545
#
# Epoch 3/499
# ----------
# train Loss: 6.1903 Acc: 0.2693
# valid Loss: 8.0355 Acc: 0.1749
#
# Epoch 4/499
# ----------
# train Loss: 5.5236 Acc: 0.3168
# valid Loss: 8.2498 Acc: 0.1856
#
# Epoch 5/499
# ----------
# train Loss: 4.8949 Acc: 0.3591
# valid Loss: 9.0866 Acc: 0.1737
#
# Epoch 6/499
# ----------
# train Loss: 4.4162 Acc: 0.3913
# valid Loss: 8.5925 Acc: 0.1892
#
# Epoch 7/499
# ----------
# train Loss: 4.0528 Acc: 0.4187
# valid Loss: 9.2130 Acc: 0.1904
#
# Epoch 8/499
# ----------
# train Loss: 3.7179 Acc: 0.4481
# valid Loss: 9.9556 Acc: 0.1772
#
# Epoch 9/499
# ----------
# train Loss: 3.3113 Acc: 0.4749
# valid Loss: 9.6740 Acc: 0.1856
#
# Epoch 10/499
# ----------
# train Loss: 3.1491 Acc: 0.4990
# valid Loss: 10.4616 Acc: 0.1725
#
# Epoch 11/499
# ----------
# train Loss: 2.7648 Acc: 0.5349
# valid Loss: 9.2898 Acc: 0.2120
#
# Epoch 12/499
# ----------
# train Loss: 2.4125 Acc: 0.5698
# valid Loss: 9.8629 Acc: 0.1641
#
# Epoch 13/499
# ----------
# train Loss: 2.1886 Acc: 0.6000
# valid Loss: 9.2545 Acc: 0.1916
#
# Epoch 14/499
# ----------
# train Loss: 1.9423 Acc: 0.6231
# valid Loss: 8.6494 Acc: 0.2072
#
# Epoch 15/499
# ----------
# train Loss: 1.8780 Acc: 0.6347
# valid Loss: 8.7834 Acc: 0.2180
#
# Epoch 16/499
# ----------
# train Loss: 1.6375 Acc: 0.6605
# valid Loss: 8.8411 Acc: 0.2048
#
# Epoch 17/499
# ----------
# train Loss: 1.5114 Acc: 0.6916
# valid Loss: 8.9910 Acc: 0.2096
#
# Epoch 18/499
# ----------
# train Loss: 1.1491 Acc: 0.7353
# valid Loss: 8.3145 Acc: 0.1940
#
# Epoch 19/499
# ----------
# train Loss: 1.0656 Acc: 0.7484
# valid Loss: 9.2279 Acc: 0.2060
#
# Epoch 20/499
# ----------
# train Loss: 0.9897 Acc: 0.7627
# valid Loss: 8.1292 Acc: 0.2228
#
# Epoch 21/499
# ----------
# train Loss: 0.9622 Acc: 0.7744
# valid Loss: 8.2516 Acc: 0.2251
#
# Epoch 22/499
# ----------
# train Loss: 0.7775 Acc: 0.8058
# valid Loss: 7.8224 Acc: 0.2275
#
# Epoch 23/499
# ----------
# train Loss: 0.6180 Acc: 0.8368
# valid Loss: 8.4709 Acc: 0.1988
#
# Epoch 24/499
# ----------
# train Loss: 0.4625 Acc: 0.8732
# valid Loss: 8.2725 Acc: 0.2120
#
# Epoch 25/499
# ----------
# train Loss: 0.4100 Acc: 0.8889
# valid Loss: 8.0414 Acc: 0.2168
#
# Epoch 26/499
# ----------
# train Loss: 0.3058 Acc: 0.9087
# valid Loss: 7.6547 Acc: 0.2180
#
# Epoch 27/499
# ----------
# train Loss: 0.1937 Acc: 0.9424
# valid Loss: 7.4321 Acc: 0.2323
#
# Epoch 28/499
# ----------
# train Loss: 0.1227 Acc: 0.9696
# valid Loss: 7.1378 Acc: 0.2383
#
# Epoch 29/499
# ----------
# train Loss: 0.0376 Acc: 0.9939
# valid Loss: 6.9857 Acc: 0.2431
#
# Epoch 30/499
# ----------
# train Loss: 0.0198 Acc: 0.9982
# valid Loss: 6.7676 Acc: 0.2515
#
# Epoch 31/499
# ----------
# train Loss: 0.0120 Acc: 1.0000
# valid Loss: 6.7045 Acc: 0.2431
#
# Epoch 32/499
# ----------
# train Loss: 0.0108 Acc: 1.0000
# valid Loss: 6.6531 Acc: 0.2491
#
# Epoch 33/499
# ----------
# train Loss: 0.0105 Acc: 1.0000
# valid Loss: 6.6078 Acc: 0.2479
#
# Epoch 34/499
# ----------
# train Loss: 0.0102 Acc: 1.0000
# valid Loss: 6.5704 Acc: 0.2515
#
# Epoch 35/499
# ----------
# train Loss: 0.0103 Acc: 1.0000
# valid Loss: 6.5008 Acc: 0.2455
#
# Epoch 36/499
# ----------
# train Loss: 0.0103 Acc: 1.0000
# valid Loss: 6.4591 Acc: 0.2467
#
# Epoch 37/499
# ----------
# train Loss: 0.0103 Acc: 1.0000
# valid Loss: 6.4016 Acc: 0.2539
#
# Epoch 38/499
# ----------
# train Loss: 0.0105 Acc: 1.0000
# valid Loss: 6.3621 Acc: 0.2467
#
# Epoch 39/499
# ----------
# train Loss: 0.0106 Acc: 1.0000
# valid Loss: 6.3172 Acc: 0.2515
#
# Epoch 40/499
# ----------
# train Loss: 0.0109 Acc: 1.0000
# valid Loss: 6.2723 Acc: 0.2503
#
# Epoch 41/499
# ----------
# train Loss: 0.0112 Acc: 1.0000
# valid Loss: 6.2297 Acc: 0.2503
#
# Epoch 42/499
# ----------
# train Loss: 0.0113 Acc: 1.0000
# valid Loss: 6.1926 Acc: 0.2527
#
# Epoch 43/499
# ----------
# train Loss: 0.0116 Acc: 1.0000
# valid Loss: 6.1563 Acc: 0.2455
#
# Epoch 44/499
# ----------
# train Loss: 0.0119 Acc: 1.0000
# valid Loss: 6.0913 Acc: 0.2467
#
# Epoch 45/499
# ----------
# train Loss: 0.0123 Acc: 1.0000
# valid Loss: 6.0557 Acc: 0.2419
#
# Epoch 46/499
# ----------
# train Loss: 0.0126 Acc: 1.0000
# valid Loss: 6.0276 Acc: 0.2491
#
# Epoch 47/499
# ----------
# train Loss: 0.0128 Acc: 1.0000
# valid Loss: 5.9837 Acc: 0.2491
#
# Epoch 48/499
# ----------
# train Loss: 0.0133 Acc: 1.0000
# valid Loss: 5.9428 Acc: 0.2455
#
# Epoch 49/499
# ----------
# train Loss: 0.0137 Acc: 1.0000
# valid Loss: 5.9104 Acc: 0.2443
#
# Epoch 50/499
# ----------
# train Loss: 0.0141 Acc: 1.0000
# valid Loss: 5.8721 Acc: 0.2503
#
# Epoch 51/499
# ----------
# train Loss: 0.0145 Acc: 1.0000
# valid Loss: 5.8280 Acc: 0.2455
#
# Epoch 52/499
# ----------
# train Loss: 0.0150 Acc: 1.0000
# valid Loss: 5.8194 Acc: 0.2395
#
# Epoch 53/499
# ----------
# train Loss: 0.0154 Acc: 1.0000
# valid Loss: 5.7641 Acc: 0.2515
#
# Epoch 54/499
# ----------
# train Loss: 0.0159 Acc: 1.0000
# valid Loss: 5.7274 Acc: 0.2407
#
# Epoch 55/499
# ----------
# train Loss: 0.0166 Acc: 1.0000
# valid Loss: 5.6872 Acc: 0.2395
#
# Epoch 56/499
# ----------
# train Loss: 0.0170 Acc: 1.0000
# valid Loss: 5.6627 Acc: 0.2443
#
# Epoch 57/499
# ----------
# train Loss: 0.0176 Acc: 1.0000
# valid Loss: 5.6284 Acc: 0.2479
#
# Epoch 58/499
# ----------
# train Loss: 0.0180 Acc: 1.0000
# valid Loss: 5.5900 Acc: 0.2383
#
# Epoch 59/499
# ----------
# train Loss: 0.0186 Acc: 1.0000
# valid Loss: 5.5633 Acc: 0.2491
#
# Epoch 60/499
# ----------
# train Loss: 0.0194 Acc: 1.0000
# valid Loss: 5.5288 Acc: 0.2455
#
# Epoch 61/499
# ----------
# train Loss: 0.0199 Acc: 1.0000
# valid Loss: 5.4940 Acc: 0.2503
#
# Epoch 62/499
# ----------
# train Loss: 0.0207 Acc: 1.0000
# valid Loss: 5.4670 Acc: 0.2443
#
# Epoch 63/499
# ----------
# train Loss: 0.0215 Acc: 1.0000
# valid Loss: 5.4210 Acc: 0.2467
#
# Epoch 64/499
# ----------
# train Loss: 0.0220 Acc: 1.0000
# valid Loss: 5.4137 Acc: 0.2431
#
# Epoch 65/499
# ----------
# train Loss: 0.0230 Acc: 1.0000
# valid Loss: 5.3698 Acc: 0.2407
#
# Epoch 66/499
# ----------
# train Loss: 0.0235 Acc: 1.0000
# valid Loss: 5.3632 Acc: 0.2455
#
# Epoch 67/499
# ----------
# train Loss: 0.0243 Acc: 1.0000
# valid Loss: 5.3523 Acc: 0.2371
#
# Epoch 68/499
# ----------
# train Loss: 0.0251 Acc: 1.0000
# valid Loss: 5.3099 Acc: 0.2359
#
# Epoch 69/499
# ----------
# train Loss: 0.0258 Acc: 1.0000
# valid Loss: 5.2844 Acc: 0.2443
#
# Epoch 70/499
# ----------
# train Loss: 0.0268 Acc: 1.0000
# valid Loss: 5.2660 Acc: 0.2323
#
# Epoch 71/499
# ----------
# train Loss: 0.0274 Acc: 1.0000
# valid Loss: 5.2430 Acc: 0.2443
#
# Epoch 72/499
# ----------
# train Loss: 0.0287 Acc: 1.0000
# valid Loss: 5.1818 Acc: 0.2467
#
# Epoch 73/499
# ----------
# train Loss: 0.0295 Acc: 1.0000
# valid Loss: 5.2000 Acc: 0.2395
#
# Epoch 74/499
# ----------
# train Loss: 0.0306 Acc: 1.0000
# valid Loss: 5.1413 Acc: 0.2383
#
# Epoch 75/499
# ----------
# train Loss: 0.0315 Acc: 1.0000
# valid Loss: 5.1321 Acc: 0.2407
#
# Epoch 76/499
# ----------
# train Loss: 0.0323 Acc: 1.0000
# valid Loss: 5.1195 Acc: 0.2383
#
# Epoch 77/499
# ----------
# train Loss: 0.0332 Acc: 1.0000
# valid Loss: 5.0750 Acc: 0.2419
#
# Epoch 78/499
# ----------
# train Loss: 0.0343 Acc: 1.0000
# valid Loss: 5.0458 Acc: 0.2419
#
# Epoch 79/499
# ----------
# train Loss: 0.0359 Acc: 1.0000
# valid Loss: 5.0561 Acc: 0.2407
#
# Epoch 80/499
# ----------
# train Loss: 0.0358 Acc: 1.0000
# valid Loss: 5.0209 Acc: 0.2323
#
# Epoch 81/499
# ----------
# train Loss: 0.0374 Acc: 1.0000
# valid Loss: 5.0005 Acc: 0.2383
#
# Epoch 82/499
# ----------
# train Loss: 0.0384 Acc: 1.0000
# valid Loss: 5.0070 Acc: 0.2419
#
# Epoch 83/499
# ----------
# train Loss: 0.0396 Acc: 1.0000
# valid Loss: 4.9863 Acc: 0.2455
#
# Epoch 84/499
# ----------
# train Loss: 0.0409 Acc: 1.0000
# valid Loss: 4.9997 Acc: 0.2311
#
# Epoch 85/499
# ----------
# train Loss: 0.0426 Acc: 1.0000
# valid Loss: 4.9086 Acc: 0.2371
#
# Epoch 86/499
# ----------
# train Loss: 0.0437 Acc: 1.0000
# valid Loss: 4.9129 Acc: 0.2407
#
# Epoch 87/499
# ----------
# train Loss: 0.0450 Acc: 1.0000
# valid Loss: 4.9115 Acc: 0.2311
#
# Epoch 88/499
# ----------
# train Loss: 0.0460 Acc: 1.0000
# valid Loss: 4.8997 Acc: 0.2347
#
# Epoch 89/499
# ----------
# train Loss: 0.0481 Acc: 1.0000
# valid Loss: 4.9093 Acc: 0.2383
#
# Epoch 90/499
# ----------
# train Loss: 0.0517 Acc: 0.9996
# valid Loss: 4.9118 Acc: 0.2431
#
# Epoch 91/499
# ----------
# train Loss: 0.0503 Acc: 0.9999
# valid Loss: 4.9491 Acc: 0.2395
#
# Epoch 92/499
# ----------
# train Loss: 0.0525 Acc: 0.9997
# valid Loss: 4.9333 Acc: 0.2491
#
# Epoch 93/499
# ----------
# train Loss: 0.0637 Acc: 0.9972
# valid Loss: 4.9748 Acc: 0.2359
#
# Epoch 94/499
# ----------
# train Loss: 0.4997 Acc: 0.8903
# valid Loss: 7.4088 Acc: 0.1629
#
# Epoch 95/499
# ----------
# train Loss: 1.9084 Acc: 0.5976
# valid Loss: 7.2288 Acc: 0.1820
#
# Epoch 96/499
# ----------
# train Loss: 1.8346 Acc: 0.6057
# valid Loss: 8.0119 Acc: 0.2072
#
# Epoch 97/499
# ----------
# train Loss: 1.6974 Acc: 0.6310
# valid Loss: 7.6268 Acc: 0.1988
#
# Epoch 98/499
# ----------
# train Loss: 1.5495 Acc: 0.6674
# valid Loss: 7.6908 Acc: 0.2156
#
# Epoch 99/499
# ----------
# train Loss: 1.4388 Acc: 0.6807
# valid Loss: 7.8899 Acc: 0.2000
#
# Epoch 100/499
# ----------
# train Loss: 1.2472 Acc: 0.7055
# valid Loss: 8.7312 Acc: 0.1988
#
# Epoch 101/499
# ----------
# train Loss: 1.0799 Acc: 0.7451
# valid Loss: 8.1134 Acc: 0.1940
#
# Epoch 102/499
# ----------
# train Loss: 1.0327 Acc: 0.7582
# valid Loss: 7.7885 Acc: 0.2132
#
# Epoch 103/499
# ----------
# train Loss: 0.7405 Acc: 0.8102
# valid Loss: 7.7019 Acc: 0.2000
#
# Epoch 104/499
# ----------
# train Loss: 0.5966 Acc: 0.8442
# valid Loss: 7.3267 Acc: 0.2263
#
# Epoch 105/499
# ----------
# train Loss: 0.5215 Acc: 0.8534
# valid Loss: 7.5426 Acc: 0.2012
#
# Epoch 106/499
# ----------
# train Loss: 0.3824 Acc: 0.8868
# valid Loss: 7.0604 Acc: 0.2335
#
# Epoch 107/499
# ----------
# train Loss: 0.2703 Acc: 0.9246
# valid Loss: 6.8929 Acc: 0.2168
#
# Epoch 108/499
# ----------
# train Loss: 0.1254 Acc: 0.9680
# valid Loss: 6.7560 Acc: 0.2275
#
# Epoch 109/499
# ----------
# train Loss: 0.0640 Acc: 0.9873
# valid Loss: 6.3137 Acc: 0.2395
#
# Epoch 110/499
# ----------
# train Loss: 0.0193 Acc: 0.9996
# valid Loss: 6.1237 Acc: 0.2491
#
# Epoch 111/499
# ----------
# train Loss: 0.0140 Acc: 1.0000
# valid Loss: 6.0457 Acc: 0.2479
#
# Epoch 112/499
# ----------
# train Loss: 0.0130 Acc: 1.0000
# valid Loss: 6.0065 Acc: 0.2491
#
# Epoch 113/499
# ----------
# train Loss: 0.0125 Acc: 1.0000
# valid Loss: 5.9474 Acc: 0.2539
#
# Epoch 114/499
# ----------
# train Loss: 0.0123 Acc: 1.0000
# valid Loss: 5.8958 Acc: 0.2491
#
# Epoch 115/499
# ----------
# train Loss: 0.0123 Acc: 1.0000
# valid Loss: 5.8720 Acc: 0.2419
#
# Epoch 116/499
# ----------
# train Loss: 0.0124 Acc: 1.0000
# valid Loss: 5.8111 Acc: 0.2419
#
# Epoch 117/499
# ----------
# train Loss: 0.0125 Acc: 1.0000
# valid Loss: 5.7930 Acc: 0.2371
#
# Epoch 118/499
# ----------
# train Loss: 0.0128 Acc: 1.0000
# valid Loss: 5.7369 Acc: 0.2431
#
# Epoch 119/499
# ----------
# train Loss: 0.0129 Acc: 1.0000
# valid Loss: 5.6961 Acc: 0.2431
#
# Epoch 120/499
# ----------
# train Loss: 0.0133 Acc: 1.0000
# valid Loss: 5.6714 Acc: 0.2443
#
# Epoch 121/499
# ----------
# train Loss: 0.0136 Acc: 1.0000
# valid Loss: 5.6124 Acc: 0.2503
#
# Epoch 122/499
# ----------
# train Loss: 0.0139 Acc: 1.0000
# valid Loss: 5.5867 Acc: 0.2503
#
# Epoch 123/499
# ----------
# train Loss: 0.0142 Acc: 1.0000
# valid Loss: 5.5559 Acc: 0.2395
#
# Epoch 124/499
# ----------
# train Loss: 0.0148 Acc: 1.0000
# valid Loss: 5.5115 Acc: 0.2407
#
# Epoch 125/499
# ----------
# train Loss: 0.0152 Acc: 1.0000
# valid Loss: 5.4911 Acc: 0.2455
#
# Epoch 126/499
# ----------
# train Loss: 0.0157 Acc: 1.0000
# valid Loss: 5.4550 Acc: 0.2455
#
# Epoch 127/499
# ----------
# train Loss: 0.0161 Acc: 1.0000
# valid Loss: 5.4169 Acc: 0.2467
#
# Epoch 128/499
# ----------
# train Loss: 0.0165 Acc: 1.0000
# valid Loss: 5.3733 Acc: 0.2371
#
# Epoch 129/499
# ----------
# train Loss: 0.0172 Acc: 1.0000
# valid Loss: 5.3447 Acc: 0.2431
#
# Epoch 130/499
# ----------
# train Loss: 0.0177 Acc: 1.0000
# valid Loss: 5.3350 Acc: 0.2335
#
# Epoch 131/499
# ----------
# train Loss: 0.0182 Acc: 1.0000
# valid Loss: 5.2835 Acc: 0.2443
#
# Epoch 132/499
# ----------
# train Loss: 0.0188 Acc: 1.0000
# valid Loss: 5.2911 Acc: 0.2443
#
# Epoch 133/499
# ----------
# train Loss: 0.0195 Acc: 1.0000
# valid Loss: 5.2276 Acc: 0.2419
#
# Epoch 134/499
# ----------
# train Loss: 0.0201 Acc: 1.0000
# valid Loss: 5.2063 Acc: 0.2515
#
# Epoch 135/499
# ----------
# train Loss: 0.0208 Acc: 1.0000
# valid Loss: 5.1616 Acc: 0.2551
#
# Epoch 136/499
# ----------
# train Loss: 0.0214 Acc: 1.0000
# valid Loss: 5.1457 Acc: 0.2419
#
# Epoch 137/499
# ----------
# train Loss: 0.0221 Acc: 1.0000
# valid Loss: 5.1210 Acc: 0.2347
#
# Epoch 138/499
# ----------
# train Loss: 0.0228 Acc: 1.0000
# valid Loss: 5.0763 Acc: 0.2407
#
# Epoch 139/499
# ----------
# train Loss: 0.0236 Acc: 1.0000
# valid Loss: 5.0785 Acc: 0.2347
#
# Epoch 140/499
# ----------
# train Loss: 0.0245 Acc: 1.0000
# valid Loss: 5.0695 Acc: 0.2383
#
# Epoch 141/499
# ----------
# train Loss: 0.0252 Acc: 1.0000
# valid Loss: 4.9964 Acc: 0.2515
#
# Epoch 142/499
# ----------
# train Loss: 0.0261 Acc: 1.0000
# valid Loss: 4.9916 Acc: 0.2443
#
# Epoch 143/499
# ----------
# train Loss: 0.0269 Acc: 1.0000
# valid Loss: 4.9488 Acc: 0.2419
#
# Epoch 144/499
# ----------
# train Loss: 0.0280 Acc: 1.0000
# valid Loss: 4.9453 Acc: 0.2467
#
# Epoch 145/499
# ----------
# train Loss: 0.0287 Acc: 1.0000
# valid Loss: 4.9175 Acc: 0.2467
#
# Epoch 146/499
# ----------
# train Loss: 0.0298 Acc: 1.0000
# valid Loss: 4.8983 Acc: 0.2359
#
# Epoch 147/499
# ----------
# train Loss: 0.0307 Acc: 1.0000
# valid Loss: 4.8847 Acc: 0.2515
#
# Epoch 148/499
# ----------
# train Loss: 0.0315 Acc: 1.0000
# valid Loss: 4.8680 Acc: 0.2407
#
# Epoch 149/499
# ----------
# train Loss: 0.0326 Acc: 1.0000
# valid Loss: 4.8653 Acc: 0.2431
#
# Epoch 150/499
# ----------
# train Loss: 0.0337 Acc: 1.0000
# valid Loss: 4.8119 Acc: 0.2323
#
# Epoch 151/499
# ----------
# train Loss: 0.0347 Acc: 1.0000
# valid Loss: 4.8046 Acc: 0.2371
#
# Epoch 152/499
# ----------
# train Loss: 0.0359 Acc: 1.0000
# valid Loss: 4.7936 Acc: 0.2395
#
# Epoch 153/499
# ----------
# train Loss: 0.0366 Acc: 1.0000
# valid Loss: 4.7604 Acc: 0.2383
#
# Epoch 154/499
# ----------
# train Loss: 0.0375 Acc: 1.0000
# valid Loss: 4.7418 Acc: 0.2443
#
# Epoch 155/499
# ----------
# train Loss: 0.0388 Acc: 1.0000
# valid Loss: 4.7298 Acc: 0.2443
#
# Epoch 156/499
# ----------
# train Loss: 0.0410 Acc: 1.0000
# valid Loss: 4.7591 Acc: 0.2347
#
# Epoch 157/499
# ----------
# train Loss: 0.0418 Acc: 1.0000
# valid Loss: 4.7323 Acc: 0.2407
#
# Epoch 158/499
# ----------
# train Loss: 0.0430 Acc: 1.0000
# valid Loss: 4.7335 Acc: 0.2407
#
# Epoch 159/499
# ----------
# train Loss: 0.0436 Acc: 1.0000
# valid Loss: 4.7031 Acc: 0.2395
#
# Epoch 160/499
# ----------
# train Loss: 0.0457 Acc: 1.0000
# valid Loss: 4.7058 Acc: 0.2431
#
# Epoch 161/499
# ----------
# train Loss: 0.0519 Acc: 0.9990
# valid Loss: 4.7142 Acc: 0.2503
#
# Epoch 162/499
# ----------
# train Loss: 0.0494 Acc: 1.0000
# valid Loss: 4.6874 Acc: 0.2467
#
# Epoch 163/499
# ----------
# train Loss: 0.0497 Acc: 0.9997
# valid Loss: 4.6824 Acc: 0.2503
#
# Epoch 164/499
# ----------
# train Loss: 0.0512 Acc: 0.9999
# valid Loss: 4.6767 Acc: 0.2371
#
# Epoch 165/499
# ----------
# train Loss: 0.0523 Acc: 0.9997
# valid Loss: 4.6790 Acc: 0.2479
#
# Epoch 166/499
# ----------
# train Loss: 0.0528 Acc: 1.0000
# valid Loss: 4.6124 Acc: 0.2443
#
# Epoch 167/499
# ----------
# train Loss: 0.0572 Acc: 0.9996
# valid Loss: 4.6470 Acc: 0.2347
#
# Epoch 168/499
# ----------
# train Loss: 0.0557 Acc: 1.0000
# valid Loss: 4.6012 Acc: 0.2491
#
# Epoch 169/499
# ----------
# train Loss: 0.0553 Acc: 1.0000
# valid Loss: 4.6264 Acc: 0.2347
#
# Epoch 170/499
# ----------
# train Loss: 0.0570 Acc: 1.0000
# valid Loss: 4.6463 Acc: 0.2371
#
# Epoch 171/499
# ----------
# train Loss: 0.0687 Acc: 0.9975
# valid Loss: 4.7895 Acc: 0.2275
#
# Epoch 172/499
# ----------
# train Loss: 0.1215 Acc: 0.9882
# valid Loss: 5.6411 Acc: 0.2192
#
# Epoch 173/499
# ----------
# train Loss: 1.4971 Acc: 0.6714
# valid Loss: 7.0932 Acc: 0.1964
#
# Epoch 174/499
# ----------
# train Loss: 2.0595 Acc: 0.5737
# valid Loss: 7.6207 Acc: 0.1844
#
# Epoch 175/499
# ----------
# train Loss: 1.8633 Acc: 0.6070
# valid Loss: 8.0873 Acc: 0.1832
#
# Epoch 176/499
# ----------
# train Loss: 1.6192 Acc: 0.6445
# valid Loss: 7.3101 Acc: 0.2012
#
# Epoch 177/499
# ----------
# train Loss: 1.3077 Acc: 0.6966
# valid Loss: 8.1849 Acc: 0.1772
#
# Epoch 178/499
# ----------
# train Loss: 1.3403 Acc: 0.6910
# valid Loss: 7.5464 Acc: 0.1796
#
# Epoch 179/499
# ----------
# train Loss: 0.9978 Acc: 0.7518
# valid Loss: 7.1734 Acc: 0.2216
#
# Epoch 180/499
# ----------
# train Loss: 0.9127 Acc: 0.7707
# valid Loss: 7.7981 Acc: 0.1964
#
# Epoch 181/499
# ----------
# train Loss: 0.8955 Acc: 0.7769
# valid Loss: 7.5442 Acc: 0.2120
#
# Epoch 182/499
# ----------
# train Loss: 0.5459 Acc: 0.8536
# valid Loss: 7.2469 Acc: 0.2240
#
# Epoch 183/499
# ----------
# train Loss: 0.5584 Acc: 0.8551
# valid Loss: 6.9925 Acc: 0.2228
#
# Epoch 184/499
# ----------
# train Loss: 0.3904 Acc: 0.8910
# valid Loss: 7.3268 Acc: 0.2060
#
# Epoch 185/499
# ----------
# train Loss: 0.2845 Acc: 0.9222
# valid Loss: 6.5939 Acc: 0.2395
#
# Epoch 186/499
# ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1073-43e72c4feda6> in <module>()
# ----> 1 train(model,dataset_sizes=dataset_sizes, train_features=conv_feat_train, train_labels=labels_train, val_features=conv_feat_val, val_labels=labels_val, criterion=criterion, optimizer=optimizer_conv_adam, num_epochs=num_epochs, train=True, shuffle=True)
#
# <ipython-input-1072-9378995d452a> in train(model, dataset_sizes, train_features, train_labels, val_features, val_labels, criterion, optimizer, num_epochs, train, shuffle)
#      23                         inputs, labels = Variable(torch.from_numpy(inputs)), Variable(torch.from_numpy(labels))
#      24                     outputs = model(inputs)
# ---> 25                     loss = criterion(outputs, labels)
#      26                     optimizer = optimizer
#      27                     optimizer.zero_grad()
#
# /Applications/anaconda/envs/carnd-term1/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# /Applications/anaconda/envs/carnd-term1/lib/python3.5/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     599         _assert_no_grad(target)
#     600         return F.cross_entropy(input, target, self.weight, self.size_average,
# --> 601                                self.ignore_index, self.reduce)
#     602
#     603
#
# KeyboardInterrupt:

# %%
model_conv = models.resnet50(pretrained=True)
for param in model_conv.parameters():
    param.requires_grad = False
num_features = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_features, num_classes)
if use_gpu:
    model_conv = model_conv.cuda()
criterion = nn.CrossEntropyLoss()
# optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=learning_rate, momentum=0.9)
optimizer_conv_adam = optim.Adam(model_conv.fc.parameters(), lr=learning_rate)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv_adam, step_size=step_size, gamma=gamma)

# %%
# model_conv = train_model(model_conv, criterion, optimizer_conv_adam, exp_lr_scheduler, num_epochs=num_epochs)

# %%
# Saving The Model:
torch.save(model_conv.state_dict(), model_weights_path)

# %%
model = torch.load(model_weights_path)

# %%
resnet18 = models.resnet18(pretrained=True)
alexnet = models.alexnet(pretrained=True)
vgg16 = models.vgg16(pretrained=True)

models_dict = {'resnet': resnet18, 'alexnet': alexnet, 'vgg': vgg16}

# %%
# obtain ImageNet labels
with open('imagenet1000_clsid_to_human.txt') as imagenet_classes_file:
    imagenet_classes_dict = ast.literal_eval(imagenet_classes_file.read())

# %%
# get_pet_labels
import os 
import pathlib
import os
import glob
import random
dirs = os.listdir("pet_images/")
petlabels_dic = {}
# print(dirs)
for image_file_name in dirs:
    label = ' '.join(image_file_name.split("_")[:-1])
    petlabels_dic[image_file_name] = label

print(petlabels_dic)
# Out:
# {'Great_pyrenees_05367.jpg': 'Great pyrenees', 'cat_07.jpg': 'cat', 'Saint_bernard_08010.jpg': 'Saint bernard', 'Boston_terrier_02303.jpg': 'Boston terrier', 'Dalmatian_04037.jpg': 'Dalmatian', 'fox_squirrel_01.jpg': 'fox squirrel', 'gecko_80.jpg': 'gecko', 'Great_dane_05320.jpg': 'Great dane', 'Beagle_01141.jpg': 'Beagle', 'German_shorthaired_pointer_04986.jpg': 'German shorthaired pointer', 'Golden_retriever_05257.jpg': 'Golden retriever', 'Poodle_07927.jpg': 'Poodle', 'Golden_retriever_05195.jpg': 'Golden retriever', 'cat_02.jpg': 'cat', 'cat_01.jpg': 'cat', 'Boston_terrier_02285.jpg': 'Boston terrier', 'Saint_bernard_08036.jpg': 'Saint bernard', 'Poodle_07956.jpg': 'Poodle', 'Cocker_spaniel_03750.jpg': 'Cocker spaniel', 'Golden_retriever_05223.jpg': 'Golden retriever', 'Boxer_02426.jpg': 'Boxer', 'Great_pyrenees_05435.jpg': 'Great pyrenees', 'Basenji_00974.jpg': 'Basenji', 'German_shepherd_dog_04890.jpg': 'German shepherd dog', 'Basset_hound_01034.jpg': 'Basset hound', 'Collie_03797.jpg': 'Collie', 'Beagle_01170.jpg': 'Beagle', 'Boston_terrier_02259.jpg': 'Boston terrier', 'Rabbit_002.jpg': 'Rabbit', 'Basenji_00963.jpg': 'Basenji', 'Golden_retriever_05182.jpg': 'Golden retriever', 'Miniature_schnauzer_06884.jpg': 'Miniature schnauzer', 'German_shepherd_dog_04931.jpg': 'German shepherd dog', 'great_horned_owl_02.jpg': 'great horned owl', 'Dalmatian_04017.jpg': 'Dalmatian', 'polar_bear_04.jpg': 'polar bear', 'skunk_029.jpg': 'skunk', 'Beagle_01125.jpg': 'Beagle', 'Dalmatian_04068.jpg': 'Dalmatian', 'gecko_02.jpg': 'gecko'}

# %%
#classify_images

# %%
img_path = "./pet_images/" + random.choice(list(petlabels_dic.keys()))
print(img_path)
# Out:
# ./pet_images/Great_dane_05320.jpg

# %%
# load the image
img_pil = Image.open(img_path)

# %%
imshow(np.asarray(img_pil))

# %%
# define transforms
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# preprocess the image
img_tensor = preprocess(img_pil)

# %%
# resize the tensor (add dimension for batch)
img_tensor.unsqueeze_(0)
# Out:
# ( 0 , 0 ,.,.) =
#   1.8037 -0.0287 -1.1075  ...   1.5639  1.5810  1.5639
#   0.3823 -0.8849 -0.9877  ...   1.5982  1.5982  1.5810
#  -1.0390 -1.0048  0.1083  ...   1.5982  1.5810  1.5810
#            ...             ⋱             ...
#   0.0398  0.0398  0.0912  ...   0.5707  0.9132  1.2214
#   0.0741  0.0569  0.0741  ...   1.7009  1.5639  1.5297
#   0.0912  0.0912  0.0227  ...   1.4954  1.8037  1.8208
#
# ( 0 , 1 ,.,.) =
#   1.7283 -0.1800 -1.2654  ...   1.5182  1.5182  1.5007
#   0.2402 -1.0378 -1.1253  ...   1.5707  1.5357  1.5182
#  -1.1954 -1.1604 -0.0224  ...   1.5532  1.5532  1.5532
#            ...             ⋱             ...
#  -0.0399 -0.0399 -0.0049  ...  -1.5630 -1.7731 -1.8256
#  -0.0049 -0.0049 -0.0224  ...   0.1176 -0.2850 -0.5826
#  -0.0049 -0.0224 -0.0574  ...  -0.5126  0.5903  0.7129
#
# ( 0 , 2 ,.,.) =
#   1.5768 -0.4624 -1.5953  ...   1.3154  1.3154  1.3328
#  -0.0092 -1.3339 -1.4559  ...   1.3154  1.2805  1.2805
#  -1.5081 -1.5081 -0.3230  ...   1.3502  1.3328  1.2457
#            ...             ⋱             ...
#  -0.0790 -0.0790 -0.0441  ...  -1.1944 -1.2816 -1.3164
#  -0.0441 -0.0267 -0.0615  ...   0.3219  0.0082 -0.2532
#  -0.0267 -0.0092 -0.0615  ...  -0.2707  0.7054  0.8797
# [torch.FloatTensor of size 1x3x224x224]

# %%
# wrap input in variable
data = Variable(img_teJnsor, volatile=True) 


# apply model to input
model = models_dict['resnet']



# puts model in evaluation mode
# instead of (default)training mode
model = model.eval()



# apply data to model
output = model(data)



# return index corresponding to predicted class
pred_idx = output.data.numpy().argmax()



imagenet_classes_dict[pred_idx]

# %%
def get_pet_labels():
    dirs = os.listdir("pet_images/")
    petlabels_dic = {}
    # print(dirs)
    for image_file_name in dirs:
        label = ' '.join(image_file_name.split("_")[:-1])
        petlabels_dic[image_file_name] = label
    return petlabels_dic

# %%
def classifier(img_path, model_name):
    # load the image
    img_pil = Image.open(img_path)
    # define transforms
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    # preprocess the image
    img_tensor = preprocess(img_pil)
    # resize the tensor (add dimension for batch)
    img_tensor.unsqueeze_(0)
    # wrap input in variable
    data = Variable(img_tensor, volatile=True) 
    # apply model to input
    model = models_dict[model_name]
    # puts model in evaluation mode
    # instead of (default)training mode
    model = model.eval()
    # apply data to model
    output = model(data)
    # return index corresponding to predicted class
    pred_idx = output.data.numpy().argmax()
    return imagenet_classes_dict[pred_idx]

# %%
def classify_images():
    results_dic = {}
#     image_filename = random.choice(list(petlabels_dic.keys()))
    for image_filename in list(petlabels_dic.keys()):
        img_path = "./pet_images/" + image_filename
        label = petlabels_dic[image_filename]
        label = label.lower()
        classification = classifier(img_path, 'resnet')
        classification = classification.split(',')[0]
        classification = classification.lower()
        match = (1 if (label == classification) else 0)
#         print(classification)
#         print(label)
#         print(1 if (label == classification) else 0)
        results_dic[image_filename] = [label, classification, match]
    print(results_dic)
    return results_dic

# %%
results_dic = classify_images()
# Out:
# {'Great_pyrenees_05367.jpg': ['great pyrenees', 'kuvasz', 0], 'cat_07.jpg': ['cat', 'egyptian cat', 0], 'Dalmatian_04068.jpg': ['dalmatian', 'dalmatian', 1], 'Dalmatian_04017.jpg': ['dalmatian', 'dalmatian', 1], 'Boston_terrier_02303.jpg': ['boston terrier', 'boston bull', 0], 'Dalmatian_04037.jpg': ['dalmatian', 'dalmatian', 1], 'fox_squirrel_01.jpg': ['fox squirrel', 'fox squirrel', 1], 'gecko_80.jpg': ['gecko', 'tailed frog', 0], 'Great_dane_05320.jpg': ['great dane', 'great dane', 1], 'Beagle_01141.jpg': ['beagle', 'beagle', 1], 'Golden_retriever_05257.jpg': ['golden retriever', 'golden retriever', 1], 'Poodle_07927.jpg': ['poodle', 'standard poodle', 0], 'great_horned_owl_02.jpg': ['great horned owl', 'great grey owl', 0], 'Boston_terrier_02259.jpg': ['boston terrier', 'boston bull', 0], 'cat_01.jpg': ['cat', 'norwegian elkhound', 0], 'Beagle_01125.jpg': ['beagle', 'beagle', 1], 'Boxer_02426.jpg': ['boxer', 'boxer', 1], 'Boston_terrier_02285.jpg': ['boston terrier', 'boston bull', 0], 'Saint_bernard_08036.jpg': ['saint bernard', 'saint bernard', 1], 'Cocker_spaniel_03750.jpg': ['cocker spaniel', 'cocker spaniel', 1], 'Golden_retriever_05223.jpg': ['golden retriever', 'golden retriever', 1], 'Great_pyrenees_05435.jpg': ['great pyrenees', 'great pyrenees', 1], 'Basenji_00974.jpg': ['basenji', 'basenji', 1], 'Saint_bernard_08010.jpg': ['saint bernard', 'saint bernard', 1], 'German_shorthaired_pointer_04986.jpg': ['german shorthaired pointer', 'german shorthaired pointer', 1], 'Collie_03797.jpg': ['collie', 'collie', 1], 'gecko_02.jpg': ['gecko', 'african chameleon', 0], 'Beagle_01170.jpg': ['beagle', 'walker hound', 0], 'Golden_retriever_05195.jpg': ['golden retriever', 'golden retriever', 1], 'Rabbit_002.jpg': ['rabbit', 'wood rabbit', 0], 'Basenji_00963.jpg': ['basenji', 'basenji', 1], 'Poodle_07956.jpg': ['poodle', 'standard poodle', 0], 'Miniature_schnauzer_06884.jpg': ['miniature schnauzer', 'miniature schnauzer', 1], 'German_shepherd_dog_04931.jpg': ['german shepherd dog', 'german shepherd', 0], 'German_shepherd_dog_04890.jpg': ['german shepherd dog', 'german shepherd', 0], 'cat_02.jpg': ['cat', 'tabby', 0], 'polar_bear_04.jpg': ['polar bear', 'ice bear', 0], 'Golden_retriever_05182.jpg': ['golden retriever', 'leonberg', 0], 'Basset_hound_01034.jpg': ['basset hound', 'basset', 0], 'skunk_029.jpg': ['skunk', 'skunk', 1]}

# %%
list_of_dognames = []

with open('dognames.txt') as f:
    for line in f:
        add_dogname = [line.strip() for line in line.split(',')]
        list_of_dognames = list_of_dognames + add_dogname
print('list_of_dognames: ', list_of_dognames)
for key in list(results_dic.keys()):
    pet_image_label = results_dic[key][0]
    classifier_label = results_dic[key][1]
    results_dic[key].append(1 if pet_image_label in list_of_dognames else 0)
    results_dic[key].append(1 if classifier_label in list_of_dognames else 0)
print('results_dic: ', results_dic)
# Out:
# list_of_dognames:  ['chihuahua', 'japanese spaniel', 'maltese dog', 'maltese terrier', 'maltese', 'pekinese', 'pekingese', 'peke', 'shih-tzu', 'blenheim spaniel', 'papillon', 'toy terrier', 'rhodesian ridgeback', 'afghan hound', 'afghan', 'basset', 'basset hound', 'beagle', 'bloodhound', 'sleuthhound', 'bluetick', 'black-and-tan coonhound', 'walker hound', 'walker foxhound', 'english foxhound', 'redbone', 'borzoi', 'russian wolfhound', 'irish wolfhound', 'italian greyhound', 'whippet', 'ibizan hound', 'ibizan podenco', 'norwegian elkhound', 'elkhound', 'otterhound', 'otter hound', 'saluki', 'gazelle hound', 'scottish deerhound', 'deerhound', 'weimaraner', 'staffordshire bullterrier', 'staffordshire bull terrier', 'american staffordshire terrier', 'staffordshire terrier', 'american pit bull terrier', 'pit bull terrier', 'bedlington terrier', 'border terrier', 'kerry blue terrier', 'irish terrier', 'norfolk terrier', 'norwich terrier', 'yorkshire terrier', 'wire-haired fox terrier', 'lakeland terrier', 'sealyham terrier', 'sealyham', 'airedale', 'airedale terrier', 'cairn', 'cairn terrier', 'australian terrier', 'dandie dinmont', 'dandie dinmont terrier', 'boston bull', 'boston terrier', 'miniature schnauzer', 'giant schnauzer', 'standard schnauzer', 'scotch terrier', 'scottish terrier', 'scottie', 'tibetan terrier', 'chrysanthemum dog', 'silky terrier', 'sydney silky', 'soft-coated wheaten terrier', 'west highland white terrier', 'lhasa', 'lhasa apso', 'flat-coated retriever', 'curly-coated retriever', 'golden retriever', 'labrador retriever', 'chesapeake bay retriever', 'german shorthaired pointer', 'vizsla', 'hungarian pointer', 'english setter', 'irish setter', 'red setter', 'gordon setter', 'brittany spaniel', 'clumber', 'clumber spaniel', 'english springer', 'english springer spaniel', 'welsh springer spaniel', 'cocker spaniel', 'english cocker spaniel', 'cocker', 'sussex spaniel', 'irish water spaniel', 'kuvasz', 'schipperke', 'groenendael', 'malinois', 'briard', 'kelpie', 'komondor', 'old english sheepdog', 'bobtail', 'shetland sheepdog', 'shetland sheep dog', 'shetland', 'collie', 'border collie', 'bouvier des flandres', 'bouviers des flandres', 'rottweiler', 'german shepherd', 'german shepherd dog', 'german police dog', 'alsatian', 'doberman', 'doberman pinscher', 'miniature pinscher', 'greater swiss mountain dog', 'bernese mountain dog', 'appenzeller', 'entlebucher', 'boxer', 'bull mastiff', 'tibetan mastiff', 'french bulldog', 'great dane', 'saint bernard', 'st bernard', 'eskimo dog', 'husky', 'malamute', 'malemute', 'alaskan malamute', 'siberian husky', 'dalmatian', 'coach dog', 'carriage dog', 'affenpinscher', 'monkey pinscher', 'monkey dog', 'basenji', 'pug', 'pug-dog', 'leonberg', 'newfoundland', 'newfoundland dog', 'great pyrenees', 'samoyed', 'samoyede', 'pomeranian', 'chow', 'chow chow', 'keeshond', 'brabancon griffon', 'pembroke', 'pembroke welsh corgi', 'cardigan', 'cardigan welsh corgi', 'toy poodle', 'miniature poodle', 'standard poodle', 'mexican hairless', 'affenpinscher', 'afghan hound', 'airedale terrier', 'akita', 'alaskan malamute', 'american eskimo dog', 'american foxhound', 'american staffordshire terrier', 'american water spaniel', 'anatolian shepherd dog', 'australian cattle dog', 'australian shepherd', 'basset hound', 'bearded collie', 'beauceron', 'belgian malinois', 'belgian sheepdog', 'belgian tervuren', 'bichon frise', 'black and tan coonhound', 'black russian terrier', 'bloodhound', 'bluetick coonhound', 'borzoi', 'boston terrier', 'bouvier des flandres', 'boykin spaniel', 'brittany', 'brussels griffon', 'bull terrier', 'bulldog', 'bullmastiff', 'cairn terrier', 'canaan dog', 'cane corso', 'cardigan welsh corgi', 'cavalier king charles spaniel', 'chinese crested', 'chinese shar-pei', 'chow chow', 'clumber spaniel', 'cocker spaniel', 'dachshund', 'dalmatian', 'dandie dinmont terrier', 'doberman pinscher', 'dogue de bordeaux', 'english cocker spaniel', 'english springer spaniel', 'english toy ...
# results_dic:  {'Great_pyrenees_05367.jpg': ['great pyrenees', 'kuvasz', 0, 1, 1], 'cat_07.jpg': ['cat', 'egyptian cat', 0, 0, 0], 'Dalmatian_04068.jpg': ['dalmatian', 'dalmatian', 1, 1, 1], 'Dalmatian_04017.jpg': ['dalmatian', 'dalmatian', 1, 1, 1], 'Boston_terrier_02303.jpg': ['boston terrier', 'boston bull', 0, 1, 1], 'Dalmatian_04037.jpg': ['dalmatian', 'dalmatian', 1, 1, 1], 'fox_squirrel_01.jpg': ['fox squirrel', 'fox squirrel', 1, 0, 0], 'gecko_80.jpg': ['gecko', 'tailed frog', 0, 0, 0], 'Great_dane_05320.jpg': ['great dane', 'great dane', 1, 1, 1], 'Beagle_01141.jpg': ['beagle', 'beagle', 1, 1, 1], 'Golden_retriever_05257.jpg': ['golden retriever', 'golden retriever', 1, 1, 1], 'Poodle_07927.jpg': ['poodle', 'standard poodle', 0, 1, 1], 'great_horned_owl_02.jpg': ['great horned owl', 'great grey owl', 0, 0, 0], 'Boston_terrier_02259.jpg': ['boston terrier', 'boston bull', 0, 1, 1], 'cat_01.jpg': ['cat', 'norwegian elkhound', 0, 0, 1], 'Beagle_01125.jpg': ['beagle', 'beagle', 1, 1, 1], 'Boxer_02426.jpg': ['boxer', 'boxer', 1, 1, 1], 'Boston_terrier_02285.jpg': ['boston terrier', 'boston bull', 0, 1, 1], 'Saint_bernard_08036.jpg': ['saint bernard', 'saint bernard', 1, 1, 1], 'Cocker_spaniel_03750.jpg': ['cocker spaniel', 'cocker spaniel', 1, 1, 1], 'Golden_retriever_05223.jpg': ['golden retriever', 'golden retriever', 1, 1, 1], 'Great_pyrenees_05435.jpg': ['great pyrenees', 'great pyrenees', 1, 1, 1], 'Basenji_00974.jpg': ['basenji', 'basenji', 1, 1, 1], 'Saint_bernard_08010.jpg': ['saint bernard', 'saint bernard', 1, 1, 1], 'German_shorthaired_pointer_04986.jpg': ['german shorthaired pointer', 'german shorthaired pointer', 1, 1, 1], 'Collie_03797.jpg': ['collie', 'collie', 1, 1, 1], 'gecko_02.jpg': ['gecko', 'african chameleon', 0, 0, 0], 'Beagle_01170.jpg': ['beagle', 'walker hound', 0, 1, 1], 'Golden_retriever_05195.jpg': ['golden retriever', 'golden retriever', 1, 1, 1], 'Rabbit_002.jpg': ['rabbit', 'wood rabbit', 0, 0, 0], 'Basenji_00963.jpg': ['basenji', 'basenji', 1, 1, 1], 'Poodle_07956.jpg': ['poodle', 'standard poodle', 0, 1, 1], 'Miniature_schnauzer_06884.jpg': ['miniature schnauzer', 'miniature schnauzer', 1, 1, 1], 'German_shepherd_dog_04931.jpg': ['german shepherd dog', 'german shepherd', 0, 1, 1], 'German_shepherd_dog_04890.jpg': ['german shepherd dog', 'german shepherd', 0, 1, 1], 'cat_02.jpg': ['cat', 'tabby', 0, 0, 0], 'polar_bear_04.jpg': ['polar bear', 'ice bear', 0, 0, 0], 'Golden_retriever_05182.jpg': ['golden retriever', 'leonberg', 0, 1, 1], 'Basset_hound_01034.jpg': ['basset hound', 'basset', 0, 1, 1], 'skunk_029.jpg': ['skunk', 'skunk', 1, 0, 0]}

# %%
#calculates_results_stats
results_stats = {}
number_of_matched = 0
number_of_dogs = 0
number_of_classified_dogs = 0
for key in list(results_dic.keys()):
    number_of_matched = number_of_matched + results_dic[key][2]
    number_of_dogs = number_of_dogs + results_dic[key][3]
    number_of_classified_dogs = number_of_classified_dogs + results_dic[key][4]
results_stats['n_matched'] = number_of_matched
results_stats['n_dogs'] = number_of_dogs
results_stats['n_classified_as_dog'] = number_of_classified_dogs
results_stats['pct_matched'] = number_of_matched/len(list(results_dic.keys()))
results_stats['pct_dogs'] = number_of_dogs/len(list(results_dic.keys()))
results_stats['pct_classified_as_dog'] = number_of_classified_dogs/len(list(results_dic.keys()))
print('results_stats: ', results_stats)
# Out:
# number_of_matched:  21
# number_of_dogs:  30
# number_of_classified_dogs:  31
# results_stats:  {'n_dogs': 30, 'n_classified_as_dog': 31, 'pct_dogs': 0.75, 'pct_matched': 0.525, 'pct_classified_as_dog': 0.775, 'n_matched': 21}

# %%
#print_results
